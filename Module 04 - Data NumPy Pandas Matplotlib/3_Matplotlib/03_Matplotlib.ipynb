# %% [markdown]
# # Matplotlib Basics
#
#
# Data Vizualization library

# %%
pyplot.py -> xlabel()

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5,6,7]
y = [50,51,52,48,47,49,46]

# %%
plt.xlabel("Day")
# Out:
# Text(0.5, 0, 'Day')

# %%
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
plt.title("Weather")
# Out:
# Text(0.5, 1.0, 'Weather')

# %%
plt.plot(x, y)

# %%
plt.plot(x,y, color='red', linewidth=2)

# %%
plt.plot(x,y, color='red', linewidth=2, linestyle='dashed')

# %%
plt.plot(x,y, color='green', linewidth=5, linestyle='dotted')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y, color='red', linewidth=2, linestyle='dashed')

# %% [markdown]
# ## format strings

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y, 'r+--')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y, color='blue', marker='*', linestyle='--')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y, color='blue', marker='^', linestyle='', markersize=10)

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y, 'g<', alpha=0.6)  # rgba -> a = alpha(opacity)

# %% [markdown]
# ## Label Parameter

# %%
days = [1,2,3,4,5,6,7]

max_t = [50,51,52,48,47,49,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,48,48,46,40,42,41]

# %%
plt.plot(days, max_t, label='max')
plt.plot(days, min_t, label='min')
plt.plot(days, avg_t, label='average')

# %% [markdown]
# ## legend

# %%
plt.plot(days, max_t, label='max')
plt.plot(days, min_t, label='min')
plt.plot(days, avg_t, label='average')

plt.legend(loc='best')

# %%
plt.plot(days, max_t, label='max')
plt.plot(days, min_t, label='min')
plt.plot(days, avg_t, label='average')

plt.legend(loc='upper right', shadow=True, fontsize='large')

# %% [markdown]
# # Bar Chart

# %%
import numpy as np

# %%
company = ['Google', 'Amazon', 'MS', 'Facebook']
revenue = [90, 136, 89, 27]

# %%
xpos = np.arange(len(company))  # 0,1,2,3

xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos, revenue, label='Revenue')
plt.ylabel('Revenue(Bln)')
plt.title('Technology Companies Stocks')
plt.legend()

# %%
plt.bar(xpos, revenue, label='Revenue')

plt.xticks(xpos, company)

plt.ylabel('Revenue(Bln)')
plt.title('Technology Companies Stocks')
plt.legend()

# %%
profit = [40,2,34,12]

# %%
plt.bar(xpos, revenue, label='Revenue')
plt.bar(xpos, profit, label='Profit')

plt.xticks(xpos, company)

plt.ylabel('Revenue(Bln)')
plt.title('Technology Companies Stocks')
plt.legend()

# %%
plt.bar(xpos - 0.2, revenue, label='Revenue')
plt.bar(xpos + 0.2, profit, label='Profit')

plt.xticks(xpos, company)

plt.ylabel('Revenue(Bln)')
plt.title('Technology Companies Stocks')
plt.legend()

# %%
plt.bar(xpos - 0.2, revenue, width=0.4, label='Revenue')
plt.bar(xpos + 0.2, profit, width=0.4, label='Profit')

plt.xticks(xpos, company)

plt.ylabel('Revenue(Bln)')
plt.title('Technology Companies Stocks')
plt.legend()

# %% [markdown]
# # Pie Chart

# %%
value = [1400,600,300,410,250]
reason = ['Home Rent', 'Food', 'Internet', 'Car', 'Others']

# %%
plt.pie(value, labels=reason)
# Out:
# ([<matplotlib.patches.Wedge at 0x2df91c79400>,
#   <matplotlib.patches.Wedge at 0x2df91c799d0>,
#   <matplotlib.patches.Wedge at 0x2df91c79f40>,
#   <matplotlib.patches.Wedge at 0x2df91c71940>,
#   <matplotlib.patches.Wedge at 0x2df91c71df0>],
#  [Text(0.09328656407206024, 1.0960372333838069, 'Home Rent'),
#   Text(-0.9822184890776084, -0.4952240298229684, 'Food'),
#   Text(-0.16284704617934698, -1.0878790555712807, 'Internet'),
#   Text(0.6256100334857941, -0.9047718419590123, 'Car'),
#   Text(1.0615045230766318, -0.28845822485734873, 'Others')])

# %%
plt.pie(value, labels=reason, autopct='%1.2f%%', radius=1.5)
# Out:
# ([<matplotlib.patches.Wedge at 0x2df916a3a90>,
#   <matplotlib.patches.Wedge at 0x2df916b41f0>,
#   <matplotlib.patches.Wedge at 0x2df916b4910>,
#   <matplotlib.patches.Wedge at 0x2df916c8070>,
#   <matplotlib.patches.Wedge at 0x2df916c87c0>],
#  [Text(0.13992984610809037, 1.6440558500757103, 'Home Rent'),
#   Text(-1.4733277336164126, -0.7428360447344526, 'Food'),
#   Text(-0.2442705692690205, -1.6318185833569212, 'Internet'),
#   Text(0.9384150502286911, -1.3571577629385183, 'Car'),
#   Text(1.5922567846149476, -0.43268733728602315, 'Others')],
#  [Text(0.07632537060441291, 0.8967577364049328, '47.30%'),
#   Text(-0.8036333092453158, -0.40518329712788315, '20.27%'),
#   Text(-0.1332384923285566, -0.8900828636492296, '10.14%'),
#   Text(0.511862754670195, -0.7402678706937371, '13.85%'),
#   Text(0.8685037006990621, -0.2360112748832853, '8.45%')])

# %% [markdown]
# # Histogram

# %%
blood_sugar = [113,85,90,150,149,88,93,115,135,80,77,82,129]

# %%
plt.hist(blood_sugar, rwidth=0.8)
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar, rwidth=0.8, bins=4)
# Out:
# (array([7., 1., 2., 3.]),
#  array([ 77.  ,  95.25, 113.5 , 131.75, 150.  ]),
#  <BarContainer object of 4 artists>)

# %%
plt.xlabel('Sugar Level')
plt.ylabel('Number of Patients')
plt.title('Blood Sugar Levels')

plt.hist(blood_sugar, bins=[80, 100], rwidth=0.9, color='b')
plt.hist(blood_sugar, bins=[100, 125], rwidth=0.9, color='g')
plt.hist(blood_sugar, bins=[125, 150], rwidth=0.9, color='r')
# Out:
# (array([4.]), array([125, 150]), <BarContainer object of 1 artists>)
